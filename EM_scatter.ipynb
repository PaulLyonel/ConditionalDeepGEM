# %%
import torch
import numpy as np
from torch import nn
from FrEIA.framework import InputNode, OutputNode, Node, GraphINN, ConditionNode
from FrEIA.modules import GLOWCouplingBlock
import FrEIA.modules as Fm

torch.set_default_dtype(torch.float64)
import matplotlib.pyplot as plt

device = 'cuda' if torch.cuda.is_available() else 'cpu'


DIMENSION = 7
ndim_y = 77

# load forward model
forward_model = nn.Sequential(nn.Linear(DIMENSION, 256), nn.ReLU(),
                              nn.Linear(256, 256), nn.ReLU(),
                              nn.Linear(256, 256), nn.ReLU(),
                              nn.Linear(256,  ndim_y)).to(device)

forward_model.load_state_dict(torch.load('forw_new.pt'))
for param in forward_model.parameters():
    param.requires_grad=False

    
    
# define hyperparameters
relu = torch.nn.ReLU()
x_total_y = 2000

# %%
# set log posterior function for mixed noise error model
def get_log_posterior(samples, forward_model, a, b, ys,lambd_bd=10):
    relu=torch.nn.ReLU()
    forward_samps=forward_model(samples)
    prefactor = ((b*forward_samps)**2+a**2)
    p = .5*torch.sum(torch.log(prefactor), dim = 1)
    p2 =  0.5*torch.sum((ys-forward_samps)**2/prefactor, dim = 1)
    p3 = lambd_bd*torch.sum(relu(samples-1)+relu(-samples), dim = 1)
    return p+p2+p3

# create normalizing flow
def create_INN(num_layers, sub_net_size):
    def subnet_fc(c_in, c_out):
        return nn.Sequential(nn.Linear(c_in, sub_net_size), nn.ReLU(),
                             nn.Linear(sub_net_size, sub_net_size), nn.ReLU(),
                             nn.Linear(sub_net_size,  c_out))

    nodes = [InputNode(DIMENSION, name='input')]
    cond = ConditionNode(ndim_y, name='condition')
    for k in range(num_layers):
        nodes.append(Node(nodes[-1],
                          GLOWCouplingBlock,
                          {'subnet_constructor':subnet_fc, 'clamp':1.4},
                          conditions = cond,
                          name=F'coupling_{k}'))
    nodes.append(OutputNode(nodes[-1], name='output'))
    model = GraphINN(nodes + [cond], verbose=False).to(device)
    return model

# em algorithm
def em_ab(a_sq_init,b_sq_init,f_x,y,steps=20):
    def compute_c1_c2(a_sq_r,b_sq_r,f_x_inp,y_inp):
        l2_dist=(y_inp-f_x_inp)**2
        c_nenner=a_sq_r+b_sq_r*f_x_inp**2
        c_nenner_sq=c_nenner**2
        v_variance=a_sq_r*b_sq_r*f_x_inp**2/c_nenner

        c1_=-(l2_dist*(1-2*a_sq_r/c_nenner+a_sq_r**2/c_nenner_sq)+v_variance)/(f_x_inp**2)
        c2_=-(l2_dist*a_sq_r**2/c_nenner_sq+v_variance)
        c1=torch.sum(c1_/y.shape[1])
        c2=torch.sum(c2_/y.shape[1])
        return c1,c2

    a_sq = a_sq_init
    b_sq = b_sq_init
    for step in range(steps):
        c1,c2=compute_c1_c2(a_sq,b_sq,f_x,y)
        a_sq_new=-c2/(y.shape[0])
        b_sq_new=-c1/(y.shape[0])

        a_sq=a_sq_new
        b_sq=b_sq_new
    return a_sq,b_sq
    
# train with forward KL
def train_inn_epoch(model,optimizer, a, b, forward_model, batch_size = 512):
    for k in range(10):
        x = torch.rand(batch_size, DIMENSION, device = device)
        ys = forward_model(x) + b*forward_model(x)*torch.randn(batch_size, ndim_y, device = device)+a*torch.randn(batch_size, ndim_y, device = device)
        optimizer.zero_grad()
        out = model(x, c = ys, rev = True)
        output = out[0].to(device)
        jac = out[1].to(device)
        l = 0.5*torch.sum(output**2)/batch_size
        l = l - torch.mean(jac)
        l.backward()
        optimizer.step()
    for k in range(1):
        ys = torch.zeros(len(meas), ndim_y, device = device)
        ys += meas.to(device)
        ys = ys.repeat(x_total_y//len(meas),1)

        z = torch.randn(len(ys), DIMENSION, device = device)

        out = model(z, c = ys)
        output = out[0].to(device)
        fx = forward_model(output)
        a,b = em_ab(a**2,b**2,fx,ys)
        a = torch.sqrt(a.abs())
        b = torch.sqrt(b.abs())
    return l,a,b

def calc_elbo(a,b,model, meas):
    with torch.no_grad():
        ys = torch.zeros(len(meas), ndim_y, device = device)
        ys += meas.to(device)
        ys = ys.repeat(2000//len(meas),1)
        z = torch.randn(len(ys), DIMENSION, device = device)
        out,jac = model(z, c = ys)
        elbo = -get_log_posterior(out, forward_model, a,b, ys).mean() + jac.mean()
    return elbo
    


def savePost(posterior, no_params, x_true, l):
    fig, axes = plt.subplots(figsize=[9,9], nrows=no_params, ncols=no_params);
    posterior = posterior[0].cpu().data.numpy()
    x_true = x_true.cpu().data.numpy().reshape(1,7)
    for j in range(no_params):
        for k in range(no_params):
            axes[j,k].get_xaxis().set_ticks([]);
            axes[j,k].get_yaxis().set_ticks([]);
            if k == 0: axes[j,k].set_ylabel(j);
            #if j == len(params)-1: axes[j,k].set_xlabel(k);
            if j == k:
                axes[k,k].hist(posterior[:,j], bins=50,  alpha=0.3,range = (0.,1.2));
                axes[k,k].hist(posterior[:,j], bins=50,  histtype="step", range = (0.,1.2));
                axes[k,k].axvline(x_true[:,j])
            else:
                val, x, y = np.histogram2d(posterior[:,j], posterior[:,k], bins=25, range = [[0., 1.2], [0., 1.2]]);
                axes[j,k].contourf(val, 8, extent=[x[0], x[-1], y[0], y[-1]], alpha=1);
    plt.tight_layout()

    plt.savefig('posterior_forw' +str(l)+'.png')

# %%
# number of measurements and number of runs for evaluation
no_meas = [1,2,4,8]
no_runs = 5
dist_list = []
elbo_list = []
a_true = 0.03
b_true = 0.25

for q in range(len(no_meas)):
    print(q)
    mean = 0
    elbo_mean = 0
    for p in range(no_runs):
        torch.manual_seed(q*no_runs+p)
        x_true = torch.rand(no_meas[q], 7, device = device)
        meas = forward_model(x_true)+b_true*torch.randn_like(forward_model(x_true), device = device)*forward_model(x_true)+a_true*torch.randn_like(forward_model(x_true), device = device)
        model = create_INN(4,256)
        a = torch.ones(1,1, device = device).clone().detach()*0.3
        b = torch.ones(1,1, device = device).clone().detach()*0.3
        
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    
        for i in range(5000):
            l,a,b = train_inn_epoch(model, optimizer, a.detach(), b.detach(),forward_model)
        elbo = calc_elbo(a,b,model,meas)
        print(elbo)
        print(a,b)
        y_meas = torch.zeros(2000,ndim_y,device = device)
        y_meas = y_meas + meas[0]
        z = torch.randn(2000,7, device = device)
        samples = model(z,c = y_meas)
        savePost(samples, 7, x_true[0], q*no_runs+p)
        ab_error = torch.abs((b-b_true))+ torch.abs((a-a_true))
        mean = mean + ab_error.cpu().data.numpy()
        elbo_mean += elbo
    dist_list.append(mean/no_runs)
    elbo_list.append(elbo_mean/no_runs)
# Out:
# 0
# tensor(165.7785, device='cuda:0')
# tensor(0.0440, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.1849, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(195.7640, device='cuda:0')
# tensor(0.0312, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.1799, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(225.7126, device='cuda:0')
# tensor(0.0270, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.7908, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(170.0866, device='cuda:0')
# tensor(0.0360, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2662, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(211.6268, device='cuda:0')
# tensor(0.0310, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.7101, device='cuda:0', grad_fn=<SqrtBackward0>)
# 1
# tensor(194.8435, device='cuda:0')
# tensor(0.0300, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2526, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(205.5254, device='cuda:0')
# tensor(0.0271, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.3072, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(176.5048, device='cuda:0')
# tensor(0.0301, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.3154, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(216.2128, device='cuda:0')
# tensor(0.0275, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.3372, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(166.4950, device='cuda:0')
# tensor(0.0336, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2899, device='cuda:0', grad_fn=<SqrtBackward0>)
# 2
# tensor(146.8946, device='cuda:0')
# tensor(0.0339, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2517, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(180.0950, device='cuda:0')
# tensor(0.0283, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2915, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(158.7087, device='cuda:0')
# tensor(0.0453, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2483, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(186.2562, device='cuda:0')
# tensor(0.0310, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2755, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(172.0444, device='cuda:0')
# tensor(0.0300, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2351, device='cuda:0', grad_fn=<SqrtBackward0>)
# 3
# tensor(178.0948, device='cuda:0')
# tensor(0.0327, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2349, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(188.8496, device='cuda:0')
# tensor(0.0314, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2828, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(173.1756, device='cuda:0')
# tensor(0.0347, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2532, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(199.7226, device='cuda:0')
# tensor(0.0331, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2443, device='cuda:0', grad_fn=<SqrtBackward0>)
# tensor(182.2286, device='cuda:0')
# tensor(0.0320, device='cuda:0', grad_fn=<SqrtBackward0>) tensor(0.2734, device='cuda:0', grad_fn=<SqrtBackward0>)

# %%
print(dist_list)
print(elbo_list)
print(torch.mean(torch.tensor(elbo_list)))
plt.figure()
plt.plot(no_meas,dist_list)
plt.xlabel("number of measurements")
plt.ylabel("distance to true a and b")
plt.savefig('forward_error_plot')
plt.show()
plt.figure()
plt.plot(no_meas,elbo_list)
plt.show()
# Out:
# [0.23549834310594747, 0.05227651265739297, 0.021440355607814883, 0.018806422548558743]
# [tensor(193.7937, device='cuda:0'), tensor(191.9163, device='cuda:0'), tensor(168.7998, device='cuda:0'), tensor(184.4142, device='cuda:0')]
# tensor(184.7310)
